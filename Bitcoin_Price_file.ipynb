# %%
# Dependencies
import pandas as pd
import numpy as np
import quandl
import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot')

# %%
# download bitcoin price
bitcoin = quandl.get("BCHAIN/MKPRU")

# %%
# data clean
bitcoin.columns = ['Close']
bitcoin['Close'].replace(0, np.nan, inplace=True)
bitcoin = bitcoin.dropna()

# %%
# plot bitcoin price
bitcoin.Close.plot(logy=True);
# plt.xlim(pd.Timestamp('2017-03-15'), pd.Timestamp('2018-03-15'))
# plt.ylim(900, 22000)
plt.legend()
plt.show()

# %%
# plot bitcoin price of last 12 months
bitcoin.Close.plot(logy=True);
plt.xlim(pd.Timestamp('2017-03-15'), pd.Timestamp('2018-03-15'))
plt.ylim(900, 22000)
plt.legend()
plt.show()

# %%
# reset index
bitcoin.reset_index(inplace=True)

# %%
# check final data frame
bitcoin.head()
bitcoin.tail()
# Out:
#            Date        Close
# 2771 2018-03-19  8171.415000
# 2772 2018-03-20  8412.033333
# 2773 2018-03-21  8986.948333
# 2774 2018-03-22  8947.753333
# 2775 2018-03-23  8690.408333

# %%
# save CSV file
bitcoin.to_csv("bitcoinPrice.csv")
